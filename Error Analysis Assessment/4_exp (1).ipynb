# %% [markdown]
# <a href="https://colab.research.google.com/github/venkata18167/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/4_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def detect_bruteforce(log_lines, threshold=5):
    ip_counts = {}
    for line in log_lines:
        if 'FAILED LOGIN' in line:
            parts = line.split(' ')
            ip = parts[4]
            ip_counts[ip] = ip_counts[ip] + 1

    flagged = []
    for ip, count in ip_counts:
        if count > threshold:
            flagged.append(ip)
    return flagged

log = [
    'FAILED LOGIN user=admin from 10.0.0.5',
    'FAILED LOGIN user=admin from 10.0.0.5',
    'FAILED LOGIN user=root from 10.0.0.5'
]
print(detect_bruteforce(log, threshold=2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1543/3522237587.py in <cell line: 0>()
#      18     'FAILED LOGIN user=root from 10.0.0.5'
#      19 ]
# ---> 20 print(detect_bruteforce(log, threshold=2))
#
# /tmp/ipykernel_1543/3522237587.py in detect_bruteforce(log_lines, threshold)
#       5             parts = line.split(' ')
#       6             ip = parts[4]
# ----> 7             ip_counts[ip] = ip_counts[ip] + 1
#       8
#       9     flagged = []
#
# KeyError: '10.0.0.5'

# %%
def detect_bruteforce(log_lines, threshold=5):
    ip_counts = {}

    for line in log_lines:
        if 'FAILED LOGIN' in line:
            parts = line.split(' ')
            ip = parts[4]

            ip_counts[ip] = ip_counts.get(ip, 0) + 1

    flagged = []
    for ip, count in ip_counts.items():
        if count >= threshold:
            flagged.append(ip)

    return flagged
log = [
    'FAILED LOGIN user=admin from 10.0.0.5',
    'FAILED LOGIN user=admin from 10.0.0.5',
    'FAILED LOGIN user=root from 10.0.0.5'
]

print(detect_bruteforce(log, threshold=2))
# Out:
# ['10.0.0.5']
