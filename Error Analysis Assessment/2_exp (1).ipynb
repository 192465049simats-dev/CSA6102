# %% [markdown]
# <a href="https://colab.research.google.com/github/venkata18167/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/2_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def classify_incident(description):
    categories = {
        'Phishing': ['fake email', 'login link', 'credential'],
        'Ransomware': ['encrypted files', 'ransom note', 'bitcoin'],
        'Identity Theft': ['stolen identity', 'aadhaar', 'pan card']
    }
    description = description.lower
    for category, keywords in categories:
        for word in keywords:
            if word in description:
                return category
    return 'Unclassified'

result = classify_incident('Victim received a fake email with a login link')
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2665/2153493694.py in <cell line: 0>()
#      12     return 'Unclassified'
#      13
# ---> 14 result = classify_incident('Victim received a fake email with a login link')
#      15 print(result)
#
# /tmp/ipykernel_2665/2153493694.py in classify_incident(description)
#       6     }
#       7     description = description.lower
# ----> 8     for category, keywords in categories:
#       9         for word in keywords:
#      10             if word in description:
#
# ValueError: too many values to unpack (expected 2)

# %%
def classify_incident(description):
    categories = {
        'Phishing': ['fake email', 'login link', 'credential'],
        'Ransomware': ['encrypted files', 'ransom note', 'bitcoin'],
        'Identity Theft': ['stolen identity', 'aadhaar', 'pan card']
    }

    description = description.lower()

    for category, keywords in categories.items():
        for word in keywords:
            if word in description:
                return category

    return 'Unclassified'

result = classify_incident('Victim received a fake email with a login link')
print(result)
# Out:
# Phishing
